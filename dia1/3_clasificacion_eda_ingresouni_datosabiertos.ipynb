# %% [markdown]
# # EDA DE DATASET DE DATOS ABIERTOS(INGRESANTES A LA UNI)
# ## DATASET : https://www.datosabiertos.gob.pe/dataset/postulantes-al-concurso-de-admisi%C3%B3n-de-la-universidad-nacional-de-ingenier%C3%ADa-uni

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH_CSV = '/content/drive/MyDrive/NOTEBOOKS/MODULO9/DATASETS/Datos_abiertos_admision_2021_1_2024_1.csv'

# %%
df = pd.read_csv(PATH_CSV)
df
# Out:
#                                                   IDHASH  \
# 0      E4287C2FE19F63C5E6641955147E36684A5A2FF8064676...
# 1      2DC37F0B9727B6591EC72D7A942647797A200F45D47C9E...
# 2      3B8677B90781D7BB8F2F967C05FA2DBBE153BBB682DF05...
# 3      FA366704D9E9F6FB5E5F55C1FB0CEEE973C626A5616F55...
# 4      E31CF8F30F3AE60B3D8A14F6E1020E9AD26EE975F0823B...
# ...                                                  ...
# 42511  370728AB03E7ECDE69265AC64B0A682887B0BA3E40644F...
# 42512  C03C7AC74210DA0F4862BFEDAE45CF3BB5AE9813FCF409...
# 42513  E6337F43BAEF0F59EDF11F6F16A47A908717DE288B7886...
# 42514  13F7CD09C661B02F61218445885DA7C4FDBD87392F7522...
# 42515  89BFAB90B1C8C25D61557264958F988E305385A9351B5C...
#
#                           COLEGIO COLEGIO_DEPA           COLEGIO_PROV  \
# 0           LA DIVINA PROVIDENCIA         LIMA                   LIMA
# 1               86019 LA LIBERTAD       ÁNCASH                 HUARAZ
# ...

# %%
df['MODALIDAD'].value_counts()
# Out:
# MODALIDAD
# ORDINARIO                                                                                            24054
# INGRESO ESCOLAR NACIONAL                                                                              7245
# EXTRAORDINARIO 2 – INGRESO DIRECTO CEPRE                                                              3666
# EXTRAORDINARIO INGRESO DIRECTO CEPRE-UNI                                                              3178
# EXTRAORDINARIO INGRESO DIRECTO CEPRE-UNI O CEPRE-UNI INTENSIVO                                        1405
# EXTRAORDINARIO2 – INGRESO DIRECTO CEPRE                                                                930
# TALENTO BECA 18                                                                                        397
# EXTRAORDINARIO - DOS PRIMEROS ALUMNOS                                                                  298
# EXTRAORDINARIO 1 - DOS PRIMEROS ALUMNOS                                                                279
# ...

# %% [markdown]
# # EDA

# %%
df.dtypes
# Out:
# IDHASH                  object
# COLEGIO                 object
# COLEGIO_DEPA            object
# COLEGIO_PROV            object
# COLEGIO_DIST            object
# COLEGIO_PAIS            object
# COLEGIO_ANIO_EGRESO      int64
# ESPECIALIDAD            object
# ANIO_POSTULA             int64
# CICLO_POSTULA            int64
# DOMICILIO_DEPA          object
# DOMICILIO_PROV          object
# DOMICILIO_DIST          object
# ANIO_NACIMIENTO          int64
# NACIMIENTO_PAIS         object
# NACIMIENTO_DEPA         object
# NACIMIENTO_PROV         object
# NACIMIENTO_DIST         object
# SEXO                    object
# CALIF_FINAL            float64
# INGRESO                 object
# MODALIDAD               object
# dtype: object

# %%
df_cleaned = df.drop(columns=['IDHASH', 'COLEGIO', 'COLEGIO_PROV','COLEGIO_DIST','COLEGIO_PAIS','DOMICILIO_DEPA','DOMICILIO_PROV','DOMICILIO_DIST','NACIMIENTO_PAIS','NACIMIENTO_DEPA','NACIMIENTO_PROV','NACIMIENTO_DIST','CALIF_FINAL','MODALIDAD'])
df_cleaned
# Out:
#       COLEGIO_DEPA  COLEGIO_ANIO_EGRESO                      ESPECIALIDAD  \
# 0             LIMA                 2020            INGENIERÍA DE SISTEMAS
# 1           ÁNCASH                 2017  INGENIERÍA DE TELECOMUNICACIONES
# 2             LIMA                 2016               INGENIERÍA MECÁNICA
# 3             LIMA                 2018            INGENIERÍA ELECTRÓNICA
# 4             LIMA                 2020                      ARQUITECTURA
# ...            ...                  ...                               ...
# 42511         LIMA                 2019                  INGENIERÍA CIVIL
# 42512       CALLAO                 2021                  INGENIERÍA CIVIL
# 42513     AYACUCHO                 2022                      ARQUITECTURA
# 42514         LIMA                 2021                      ARQUITECTURA
# 42515         LIMA                 2021            INGENIERÍA DE SISTEMAS
#
#        ANIO_POSTULA  CICLO_POSTULA  ANIO_NACIMIENTO       SEXO INGRESO
# ...

# %%
df_cleaned['egreso_postulacion'] = df_cleaned['ANIO_POSTULA'] - df_cleaned['COLEGIO_ANIO_EGRESO']
df_cleaned['edad'] = df_cleaned['ANIO_POSTULA'] - df_cleaned['ANIO_NACIMIENTO']
df_cleaned
# Out:
#       COLEGIO_DEPA  COLEGIO_ANIO_EGRESO                      ESPECIALIDAD  \
# 0             LIMA                 2020            INGENIERÍA DE SISTEMAS
# 1           ÁNCASH                 2017  INGENIERÍA DE TELECOMUNICACIONES
# 2             LIMA                 2016               INGENIERÍA MECÁNICA
# 3             LIMA                 2018            INGENIERÍA ELECTRÓNICA
# 4             LIMA                 2020                      ARQUITECTURA
# ...            ...                  ...                               ...
# 42511         LIMA                 2019                  INGENIERÍA CIVIL
# 42512       CALLAO                 2021                  INGENIERÍA CIVIL
# 42513     AYACUCHO                 2022                      ARQUITECTURA
# 42514         LIMA                 2021                      ARQUITECTURA
# 42515         LIMA                 2021            INGENIERÍA DE SISTEMAS
#
#        ANIO_POSTULA  CICLO_POSTULA  ANIO_NACIMIENTO       SEXO INGRESO  \
# ...

# %%
df_cleaned = df_cleaned.drop(columns=['COLEGIO_ANIO_EGRESO', 'ANIO_POSTULA', 'CICLO_POSTULA','ANIO_NACIMIENTO'])
df_cleaned
# Out:
#       COLEGIO_DEPA                      ESPECIALIDAD       SEXO INGRESO  \
# 0             LIMA            INGENIERÍA DE SISTEMAS  MASCULINO      NO
# 1           ÁNCASH  INGENIERÍA DE TELECOMUNICACIONES   FEMENINO      NO
# 2             LIMA               INGENIERÍA MECÁNICA  MASCULINO      NO
# 3             LIMA            INGENIERÍA ELECTRÓNICA  MASCULINO      NO
# 4             LIMA                      ARQUITECTURA   FEMENINO      NO
# ...            ...                               ...        ...     ...
# 42511         LIMA                  INGENIERÍA CIVIL  MASCULINO      NO
# 42512       CALLAO                  INGENIERÍA CIVIL   FEMENINO      NO
# 42513     AYACUCHO                      ARQUITECTURA   FEMENINO      NO
# 42514         LIMA                      ARQUITECTURA   FEMENINO      NO
# 42515         LIMA            INGENIERÍA DE SISTEMAS  MASCULINO      NO
#
#        egreso_postulacion  edad
# 0                       1    17
# 1                       4    20
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# COLEGIO_DEPA          226
# ESPECIALIDAD           55
# SEXO                    0
# INGRESO                 0
# egreso_postulacion      0
# edad                    0
# dtype: int64

# %%
df_cleaned = df_cleaned.dropna()
df_cleaned
# Out:
#       COLEGIO_DEPA                      ESPECIALIDAD       SEXO INGRESO  \
# 0             LIMA            INGENIERÍA DE SISTEMAS  MASCULINO      NO
# 1           ÁNCASH  INGENIERÍA DE TELECOMUNICACIONES   FEMENINO      NO
# 2             LIMA               INGENIERÍA MECÁNICA  MASCULINO      NO
# 3             LIMA            INGENIERÍA ELECTRÓNICA  MASCULINO      NO
# 4             LIMA                      ARQUITECTURA   FEMENINO      NO
# ...            ...                               ...        ...     ...
# 42511         LIMA                  INGENIERÍA CIVIL  MASCULINO      NO
# 42512       CALLAO                  INGENIERÍA CIVIL   FEMENINO      NO
# 42513     AYACUCHO                      ARQUITECTURA   FEMENINO      NO
# 42514         LIMA                      ARQUITECTURA   FEMENINO      NO
# 42515         LIMA            INGENIERÍA DE SISTEMAS  MASCULINO      NO
#
#        egreso_postulacion  edad
# 0                       1    17
# 1                       4    20
# ...

# %%
df_cleaned.to_csv('uni_cleaned.csv',index=None)
