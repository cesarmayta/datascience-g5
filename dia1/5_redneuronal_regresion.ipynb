# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('penguins').dropna()
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
df['species'].value_counts()
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
df_adelie = df[df['species'] == 'Adelie']
df_adelie
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 147       3475.0  Female
# 148       3450.0  Female
# 149       3750.0    Male
# 150       3700.0  Female
# 151       4000.0    Male
#
# [146 rows x 7 columns]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_adelie['flipper_length_mm'], df_adelie['body_mass_g'], alpha=0.7)
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Body Mass (g)')
plt.title('Flipper Length vs. Body Mass for Adelie Penguins')
plt.grid(True)
plt.show()

# %%
X = df[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm']]
y = df['body_mass_g'].values.reshape(-1,1)

# %% [markdown]
# # CREAMOS RED NEURONAL PARA PREDECIR EL PESO DE PINGUINO

# %% [markdown]
# ## PASO 1 - IMPORTAMOS LIBRERIAS NECESARIAS

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import Input

# %% [markdown]
# ## PASO 2 - ESCALAMOS DATOS

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y)

# %% [markdown]
# ## PASO 3 - DIVIDAMOS DATASET EN ENTRENAMIENTO Y PRUEBA

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %% [markdown]
# ## PASO 4 - CREAMOS LA RED NEURONAL

# %%
red = Sequential()
inputs = Input(shape=(3,))
entrada = Dense(units=3,activation='relu')
oculta1 = Dense(units=64,activation='relu')
oculta2 = Dense(units=32,activation='relu')
salida = Dense(units=1,activation='relu')

red.add(entrada)
red.add(oculta1)
red.add(Dropout(0.5))
red.add(oculta2)
red.add(salida)

red
# Out:
# <Sequential name=sequential_4, built=False>

# %% [markdown]
# ## PASO 5- COMPILAMOS LA RED

# %%
red.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# %% [markdown]
# ## PASO 6 - ENTRENAMOS LA RED NEURONAL

# %%
history = red.fit(X_train,y_train,epochs=50,batch_size=128,validation_split=0.2,validation_data=(X_test,y_test))
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.7399 - mae: 0.7247 - val_loss: 0.6393 - val_mae: 0.6784
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.6762 - mae: 0.6913 - val_loss: 0.5928 - val_mae: 0.6486
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.6466 - mae: 0.6795 - val_loss: 0.5586 - val_mae: 0.6296
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6013 - mae: 0.6457 - val_loss: 0.5361 - val_mae: 0.6168
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5450 - mae: 0.6093 - val_loss: 0.5259 - val_mae: 0.6086
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5771 - mae: 0.6331 - val_loss: 0.5262 - val_mae: 0.6063
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5940 - mae: 0.6454 - val_loss: 0.5301 - val_mae: 0.6105
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5659 - mae: 0.6327 - val_loss: 0.5310 - val_mae: 0.6120
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5720 - mae: 0.6297 - val_loss: 0.5261 - val_mae: 0.6078
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5881 - mae: 0.6446 - val_loss: 0.5177 - val_mae: 0.5994
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5814 - mae: 0.6418 - val_loss: 0.5102 - val_mae: 0.5923
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5568 - mae: 0.6181 - val_loss: 0.5060 - val_mae: 0.5885
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5969 - mae: 0.6549 - val_loss: 0.5046 - val_mae: 0.5873
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5451 - mae: 0.6089 - val_loss: 0.5046 - val_mae: 0.5868
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5450 - mae: 0.6128 - val_loss: 0.5052 - val_mae: 0.5868
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5497 - mae: 0.6162 - val_loss: 0.5048 - val_mae: 0.5864
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5496 - mae: 0.6159 - val_loss: 0.5035 - val_mae: 0.5853
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5416 - mae: 0.5965 - val_loss: 0.5030 - val_mae: 0.5848
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5608 - mae: 0.6212 - val_loss: 0.5027 - val_mae: 0.5844
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5562 - mae: 0.6163 - val_loss: 0.5020 - val_mae: 0.5837
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5620 - mae: 0.6264 - val_loss: 0.5017 - val_mae: 0.5834
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5389 - mae: 0.6098 - val_loss: 0.5006 - val_mae: 0.5822
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5697 - mae: 0.6315 - val_loss: 0.4993 - val_mae: 0.5809
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5656 - mae: 0.6249 - val_loss: 0.4984 - val_mae: 0.5798
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5342 - mae: 0.6044 - val_loss: 0.4979 - val_mae: 0.5791
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5539 - mae: 0.6206 - val_loss: 0.4977 - val_mae: 0.5789
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5324 - mae: 0.6024 - val_loss: 0.4981 - val_mae: 0.5794
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5564 - mae: 0.6207 - val_loss: 0.4989 - val_mae: 0.5801
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5402 - mae: 0.6030 - val_loss: 0.4997 - val_mae: 0.5805
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5238 - mae: 0.6047 - val_loss: 0.4992 - val_mae: 0.5799
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5345 - mae: 0.6049 - val_loss: 0.4970 - val_mae: 0.5777
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5368 - mae: 0.6085 - val_loss: 0.4954 - val_mae: 0.5753
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5420 - mae: 0.6168 - val_loss: 0.4950 - val_mae: 0.5757
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5345 - mae: 0.6056 - val_loss: 0.4949 - val_mae: 0.5757
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.5617 - mae: 0.6281 - val_loss: 0.4946 - val_mae: 0.5752
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5218 - mae: 0.5987 - val_loss: 0.4942 - val_mae: 0.5742
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5472 - mae: 0.6128 - val_loss: 0.4943 - val_mae: 0.5736
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5504 - mae: 0.6136 - val_loss: 0.4944 - val_mae: 0.5741
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5469 - mae: 0.6095 - val_loss: 0.4944 - val_mae: 0.5742
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5070 - mae: 0.5820 - val_loss: 0.4948 - val_mae: 0.5748
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5217 - mae: 0.5942 - val_loss: 0.4951 - val_mae: 0.5749
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5379 - mae: 0.6100 - val_loss: 0.4950 - val_mae: 0.5749
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5582 - mae: 0.6164 - val_loss: 0.4954 - val_mae: 0.5754
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5207 - mae: 0.6034 - val_loss: 0.4958 - val_mae: 0.5759
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.5241 - mae: 0.6038 - val_loss: 0.4954 - val_mae: 0.5755
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5126 - mae: 0.5893 - val_loss: 0.4940 - val_mae: 0.5739
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5568 - mae: 0.6177 - val_loss: 0.4927 - val_mae: 0.5720
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5271 - mae: 0.6004 - val_loss: 0.4920 - val_mae: 0.5710
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5361 - mae: 0.6053 - val_loss: 0.4915 - val_mae: 0.5708
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5339 - mae: 0.5994 - val_loss: 0.4913 - val_mae: 0.5705

# %% [markdown]
# # EVALUAMOS LA RED

# %%
loss, mae = red.evaluate(X_test, y_test, verbose=0)
print(f'loss evaluate : {loss}')
print(f' mae evaluate : {mae}')
# Out:
# loss evaluate : 0.4912906587123871
#  mae evaluate : 0.5704838633537292

# %%
# 📈 Gráfico de pérdida
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.title('Pérdida durante el entrenamiento')
plt.show()

# %%
# 🔍 Predicciones
y_pred = red.predict(X_test).flatten()

# 📉 Comparar predicción vs valor real
plt.scatter(y_test, y_pred, alpha=0.7)
plt.xlabel('Peso real (g)')
plt.ylabel('Peso predicho (g)')
plt.title('Predicción del peso de pingüinos')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
plt.grid(True)
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d783ac6cf40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
