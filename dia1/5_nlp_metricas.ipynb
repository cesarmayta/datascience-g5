# %% [markdown]
# # IMPORTAMOS LIBRERIAS Y DESCARGAMOS CORPUS DE LIBROS

# %%
import nltk
nltk.download('book')
from nltk.book import *
import matplotlib.pyplot as plt
import numpy as np
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection book
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# # ANALIZAMOS EL LIBRO TEXT1

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.tokens[:10]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.']

# %%
len(text1)
# Out:
# 260819

# %% [markdown]
# # METRICAS PARA TEXTOS

# %% [markdown]
# ## Medida de riqueza lexica en un texto:
#
# Calcular algunas metricas sobre el texto
#
# Cuando tenemos un texto, es normal que algunas palabras se repitan. Queremos definir cuantas palabras unicas se utilizaron respecto al total de palabras del texto. Cuanto mas grande sea nuestra riqueza lexica, mas palabras diferentes utilizo nuestro autor.
#
# $$ R_l = \frac{\text{total de palabras únicas}}{\text{total de palabras}} = \frac{\text{longitud del vocabulario}}{\text{longitud del texto}}$$

# %% [markdown]
# Primero realizamos la construcción de un vocabulario (identificamos las palabras unicas que hay en el libro)
#
# Utilizamos la funcion [set()](https://docs.python.org/2/library/sets.html), esta toma la lista de tokens y elimina repetidos, dejando una lista de palabras, con una estructura de datos sort. Para convertirlo a otra estructura usamos **sorted()**. Con esta funcion ordenamos alfabeticamente nuestro set y lo convertimos en lista.

# %%
vocabulario = sorted(set(text1))
print(vocabulario[1000:1050])
# Out:
# ['Crew', 'Crish', 'Crockett', 'Cross', 'Crossed', 'Crossing', 'Crotch', 'Crowding', 'Crown', 'Crozetts', 'Cruelty', 'Cruising', 'Cruppered', 'Crusaders', 'Crushed', 'Crying', 'Cuba', 'Curious', 'Curse', 'Cursed', 'Curses', 'Cussed', 'Customs', 'Cut', 'Cutter', 'Cutting', 'Cuvier', 'Cyclades', 'Czar', 'D', 'DAGGOO', 'DAM', 'DANCE', 'DANCING', 'DANIEL', 'DANISH', 'DARKENS', 'DARWIN', 'DAVENANT', 'DEAD', 'DEATH', 'DEBELL', 'DECK', 'DEL', 'DESTROYED', 'DEVIL', 'DICTIONARY', 'DID', 'DIGNITY', 'DISCOVERS']

# %%
rl = len(vocabulario) / len(text1)
print(rl)
# Out:
# 0.07406285585022564

# %% [markdown]
# ## CREAMOS UNA FUNCIÓN PARA MEDIR LA RIQUEZA LEXICA

# %%
def riqueza_lexica(texto):
  vocabulario = sorted(set(texto))
  rl = len(vocabulario) / len(texto)
  return rl

# %%
riqueza_lexica(text1)
# Out:
# 0.07406285585022564

# %% [markdown]
# # CREAMOS UNA FUNCIÓN PARA MEDIR EL PORCENTAJE DE UNA PALABRA CON RESPECTO AL CORPUS

# %%
def porcentaje_palabra(palabra, texto):
  porcentaje_palabra = 100 * texto.count(palabra)/len(texto)
  return porcentaje_palabra

# %%
text1.count('whale')
# Out:
# 906

# %%
porcentaje_palabra('whale', text1)
# Out:
# 0.3473673313677301

# %% [markdown]
# ## Estadistica del Lenguaje
#
# Los cálculos estadísticos más simples que se pueden efectuar sobre un texto o un corpus son los relacionados con frecuencia de aparición de palabras.
#
# * Podemos construir un diccionario en Python donde las llaves sean las palabras y los valores sean las frecuencias de ocurrencias de esas palabras.
#
# * ejemplo `dic = {'monster': 49 ,  'boat': 54,  ...}`

# %%
# Realizar un for básico, computacionalmete es muy pesado si tenemos muchos tokens
dic = {}
for palabra in set(text1):
  dic[palabra] = text1.count(palabra)
dic
# Out:
# {'gaining': 9,
#  'impresses': 1,
#  'outdone': 1,
#  'magnification': 1,
#  'pluck': 2,
#  'transfigured': 1,
#  'unbegun': 1,
#  'suspense': 2,
#  'content': 18,
#  'dismasting': 1,
#  'rejoicing': 2,
#  'peculiarly': 6,
#  'bursting': 12,
#  'Pitchpoling': 1,
#  'helmeted': 3,
#  'Nick': 1,
#  'allegorical': 1,
#  'singular': 9,
#  'capacious': 2,
#  'overflowed': 1,
#  'shroud': 10,
#  'malice': 12,
#  'icicle': 1,
#  'BACON': 1,
#  'standing': 73,
#  'disturbing': 2,
#  'austere': 1,
#  'dollars': 7,
#  'alternating': 4,
#  'kingdoms': 1,
#  'trying': 17,
#  'powder': 9,
#  'superfluous': 3,
#  'divineness': 2,
#  'absorbingly': 1,
#  'hose': 2,
#  'considered': 14,
#  'brag': 2,
#  'complimentary': 1,
#  'Krusensterns': 1,
#  'garters': 1,
#  'harbours': 1,
#  'ladder': 12,
#  'questionings': 1,
#  'intersecting': 1,
#  'cordially': 1,
#  'unchristian': 1,
#  'Unmindful': 1,
#  'grief': 7,
#  'drowning': 3,
#  'Martin': 2,
#  'subterranean': 6,
#  'extras': 1,
#  'apple': 4,
#  'jingle': 1,
#  'throw': 13,
#  'ample': 3,
#  'timidity': 4,
#  '150': 1,
#  'ding': 4,
#  'ambergris': 12,
#  'indication': 2,
#  'Scenes': 1,
#  'trample': 1,
#  'grub': 1,
#  'region': 5,
#  'pestilent': 2,
#  'goadings': 1,
#  'including': 8,
#  'off': 217,
#  'meadows': 3,
#  'pestiferously': 1,
#  'sermon': 3,
#  'Hanoverian': 1,
#  'agrarian': 1,
#  'colours': 5,
#  'chapters': 7,
#  'smile': 5,
#  'hindmost': 1,
#  'sorry': 6,
#  'Britons': 1,
#  'stead': 1,
#  'scratches': 2,
#  'operate': 2,
#  'holidays': 2,
#  'Bout': 1,
#  'upper': 30,
#  'hunts': 2,
#  'combinedly': 1,
#  'sensible': 9,
#  'sideboard': 3,
#  'indispensableness': 1,
#  'Fellow': 1,
#  'finish': 2,
#  'wriggles': 1,
#  'Holland': 5,
#  'sprain': 1,
#  'dancing': 7,
#  'inconclusive': 1,
#  'Parisians': 1,
#  'beaker': 1,
#  'Into': 2,
#  'INTO': 1,
#  'beheading': 1,
#  'unfrequented': 1,
#  'eventuated': 1,
#  'PHIL': 1,
#  'moisture': 4,
#  'incoherently': 1,
#  'exercises': 1,
#  'going': 83,
#  'thoughtful': 1,
#  'historians': 1,
#  'tortoise': 1,
#  'patience': 3,
#  'downright': 5,
#  'hornpipe': 1,
#  'ECKERMANN': 1,
#  'assembly': 1,
#  'visitation': 1,
#  'supplemental': 2,
#  'almanac': 2,
#  'enchantment': 1,
#  'convey': 1,
#  'Fish': 33,
#  'rafts': 1,
#  'drag': 15,
#  'leaps': 4,
#  'Uncommonly': 1,
#  'afterwards': 24,
#  'join': 8,
#  'offence': 1,
#  'slaughtered': 2,
#  'decorated': 1,
#  'Ten': 2,
#  'eyelids': 1,
#  'doze': 5,
#  'overbearing': 4,
#  'adds': 1,
#  'imperfectly': 1,
#  'Wife': 1,
#  'choked': 3,
#  'Titans': 1,
#  'virgin': 6,
#  'ferule': 2,
#  'mints': 1,
#  'inkstand': 1,
#  'Towards': 7,
#  'continuously': 2,
#  'Corlears': 1,
#  'Popayan': 1,
#  'providential': 1,
#  'slices': 2,
#  'chance': 46,
#  'masked': 2,
#  'northern': 7,
#  'condescending': 1,
#  'prints': 5,
#  'thinned': 1,
#  'eight': 24,
#  'mystifying': 1,
#  'junks': 2,
#  'lacquered': 2,
#  'arrant': 1,
#  'herons': 1,
#  'sinew': 1,
#  'cluster': 4,
#  'tumbled': 5,
#  'assails': 1,
#  'Nose': 1,
#  'dictator': 2,
#  'Take': 19,
#  'lad': 23,
#  'Judgment': 3,
#  'occasional': 9,
#  'unhesitatingly': 1,
#  'touched': 13,
#  'wantonness': 1,
#  'SENATE': 1,
#  'potatoes': 1,
#  'japonicas': 1,
#  'inculcating': 2,
#  'shields': 1,
#  'worship': 11,
#  'Leviathanic': 4,
#  '58': 1,
#  'quarried': 2,
#  'favoured': 1,
#  'prying': 3,
#  'squeezed': 2,
#  'energies': 1,
#  'Skeleton': 1,
#  'pedlars': 1,
#  'PLENTY': 1,
#  'frowned': 1,
#  'smelling': 3,
#  'TOP': 1,
#  'ticking': 1,
#  'bigness': 3,
#  'Ecclesiastes': 1,
#  'glittering': 8,
#  'seignories': 1,
#  'doom': 15,
#  'George': 10,
#  'wrench': 3,
#  'situated': 1,
#  'require': 4,
#  'abhorring': 1,
#  '16': 1,
#  'Great': 13,
#  'dirgelike': 1,
#  'Herr': 1,
#  'granting': 2,
#  'approaches': 1,
#  'cucumbers': 1,
#  'Turkey': 1,
#  'important': 19,
#  'engraved': 2,
#  'mouldy': 5,
#  'evaporates': 1,
#  'test': 4,
#  'stammer': 1,
#  'hag': 1,
#  'charnel': 1,
#  'antediluvian': 3,
#  'cooking': 2,
#  'demonstrable': 1,
#  'adoption': 1,
#  'pilau': 1,
#  'title': 7,
#  'mutely': 2,
#  'collated': 1,
#  'deposited': 1,
#  'classed': 1,
#  'observance': 1,
#  'skewer': 3,
#  'revolved': 5,
#  'loathed': 1,
#  'precaution': 1,
#  'tempered': 3,
#  'invocation': 1,
#  'pulling': 22,
#  'Southerner': 1,
#  'autumn': 1,
#  'bats': 1,
#  'largest': 19,
#  'luridly': 1,
#  'heathen': 3,
#  'wooded': 1,
#  'PITCHING': 1,
#  'abeam': 1,
#  'consign': 1,
#  'disguises': 1,
#  'assume': 3,
#  'lids': 2,
#  'queenly': 1,
#  'dreary': 6,
#  'REVENGE': 1,
#  'centaurs': 2,
#  'ANIMAL': 1,
#  'out': 529,
#  'tickled': 3,
#  'sooner': 13,
#  'entertaining': 2,
#  'whipping': 2,
#  'authority': 8,
#  'waxed': 1,
#  'Blue': 2,
#  'exterminated': 1,
#  'communicated': 1,
#  'enhances': 2,
#  'LATIN': 1,
#  'Icy': 3,
#  'ruined': 1,
#  'couples': 1,
#  'easily': 9,
#  'echoes': 1,
#  'Consequently': 1,
#  'mathematically': 1,
#  'higher': 23,
#  'interesting': 8,
#  'dreamed': 3,
#  'pecked': 1,
#  'believers': 1,
#  'Ahoy': 2,
#  'wink': 1,
#  'twenty': 33,
#  'named': 11,
#  'Siberia': 2,
#  'shut': 11,
#  'acridness': 1,
#  'fourteen': 1,
#  'RED': 1,
#  'armies': 4,
#  'engine': 1,
#  'still': 299,
#  'paper': 6,
#  'Killed': 2,
#  'sticks': 4,
#  'impulsively': 1,
#  'relinquish': 3,
#  'genial': 4,
#  'instinct': 8,
#  'whereof': 4,
#  'grand': 43,
#  'awake': 9,
#  'Removing': 2,
#  'visit': 10,
#  'bedded': 2,
#  'Divine': 2,
#  'harness': 1,
#  'Setting': 2,
#  'sultry': 3,
#  'enable': 4,
#  'mute': 3,
#  'witnessing': 2,
#  'Brighggians': 1,
#  'TASHTEGO': 3,
#  'eloquently': 1,
#  'handles': 3,
#  'REFERENCE': 1,
#  'SHALL': 2,
#  'intensely': 4,
#  'accommodate': 2,
#  'rolls': 14,
#  'convalescence': 1,
#  'spoons': 2,
#  'vices': 3,
#  'edging': 1,
#  'Burton': 2,
#  'prayed': 2,
#  'instance': 18,
#  'Subs': 1,
#  'tiara': 1,
#  'finical': 1,
#  'thickening': 1,
#  'tinkering': 1,
#  'grandissimus': 1,
#  'brand': 2,
#  'SAID': 1,
#  'furiously': 6,
#  'grotesque': 2,
#  'semiweekly': 1,
#  'phrenologist': 1,
#  'globules': 2,
#  'protect': 2,
#  'Doom': 1,
#  'vertu': 2,
#  'hell': 14,
#  'RABELAIS': 1,
#  'unpolluted': 1,
#  'straits': 11,
#  'yellow': 22,
#  'spraining': 1,
#  'Evangelist': 1,
#  'us': 228,
#  'infatuation': 1,
#  'gradual': 2,
#  'mortally': 2,
#  'visited': 7,
#  'noble': 44,
#  'counters': 1,
#  'revealed': 18,
#  'STERN': 1,
#  'duels': 1,
#  'imperfect': 2,
#  'River': 1,
#  'Espying': 1,
#  'whiff': 1,
#  'JEFFERSON': 1,
#  'ridiculous': 5,
#  'ungentlemanly': 1,
#  'Stowing': 1,
#  'Just': 7,
#  'unfurling': 1,
#  'Colossus': 1,
#  'de': 34,
#  'whelmed': 3,
#  'mouts': 1,
#  'fleetness': 3,
#  'BLACKSMITH': 1,
#  'Tower': 4,
#  'dissolved': 1,
#  'accompany': 2,
#  'voices': 7,
#  'stores': 2,
#  'hoofs': 3,
#  'Astronomy': 1,
#  'district': 3,
#  'suffered': 1,
#  'wonderfulness': 1,
#  'immemorially': 2,
#  'stiff': 9,
#  'to': 4542,
#  'blow': 26,
#  'conception': 2,
#  'icebound': 1,
#  'bigger': 2,
#  'management': 6,
#  'tilted': 2,
#  'temples': 2,
#  'deadliest': 3,
#  'Pandects': 1,
#  'enjoining': 1,
#  'compendious': 1,
#  'blown': 5,
#  'um': 7,
#  'myrrh': 1,
#  'greybeards': 1,
#  'figure': 19,
#  'indecorous': 1,
#  'poring': 2,
#  'canes': 2,
#  'crouches': 1,
#  'delicious': 3,
#  'Nevertheless': 27,
#  'Duke': 8,
#  'Mounttop': 4,
#  'attempt': 9,
#  'imputation': 2,
#  'phenomena': 1,
#  'courtesy': 4,
#  'knocks': 1,
#  'ostentatious': 2,
#  'artists': 1,
#  'coffin': 36,
#  'knotted': 5,
#  'WILLIS': 1,
#  'sluggish': 2,
#  'horn': 12,
#  'intermediate': 3,
#  'conjunctures': 1,
#  'tame': 4,
#  'soundest': 2,
#  'treasures': 3,
#  'arching': 1,
#  'Pedestrians': 1,
#  'glazier': 1,
#  'unconquerable': 4,
#  'Beneath': 2,
#  'leakage': 1,
#  'received': 26,
#  'embarks': 1,
#  'secretly': 2,
#  'needles': 11,
#  'weighty': 3,
#  'ants': 1,
#  'sorrowful': 1,
#  'fish': 133,
#  'given': 36,
#  'gem': 1,
#  'composing': 4,
#  'ducked': 1,
#  'kindle': 1,
#  'corsairs': 1,
#  'levers': 1,
#  'omnipresent': 1,
#  'Sperma': 1,
#  'receives': 3,
#  'glued': 4,
#  'highway': 2,
#  'backed': 8,
#  'embarrassed': 1,
#  '.*--': 1,
#  'lips': 18,
#  'HALF': 1,
#  'hypothesis': 2,
#  'ravens': 1,
#  'elevating': 3,
#  'Tyre': 1,
#  'prouder': 3,
#  'image': 11,
#  'unceasingly': 3,
#  'incidents': 1,
#  'furnace': 3,
#  'Day': 4,
#  'praying': 3,
#  'adopted': 2,
#  'common': 48,
#  'Serious': 1,
#  'habitudes': 1,
#  'antlers': 1,
#  'mugs': 1,
#  'ROLL': 1,
#  'Tell': 11,
#  'canticle': 1,
#  'rigorous': 1,
#  'baptismal': 1,
#  'occupied': 9,
#  'babe': 1,
#  'tiled': 1,
#  'gaping': 3,
#  'odorous': 3,
#  'warming': 2,
#  'headlong': 7,
#  'pedlar': 1,
#  'nonsense': 4,
#  'officer': 15,
#  'comets': 1,
#  "?'--'": 1,
#  'hams': 4,
#  'mystical': 9,
#  'obviously': 1,
#  'BOARD': 1,
#  'inlaying': 1,
#  'Truly': 2,
#  'blinds': 10,
#  'scrape': 6,
#  'snort': 1,
#  ',': 18713,
#  'fro': 17,
#  'bet': 1,
#  'gates': 2,
#  'met': 18,
#  'Leaning': 1,
#  'fluking': 1,
#  'undressed': 3,
#  'generic': 4,
#  'maple': 1,
#  'entrails': 1,
#  'constellations': 1,
#  'Nearly': 1,
#  'unsheathes': 1,
#  'anguish': 8,
#  'insist': 2,
#  'shark': 27,
#  'White': 89,
#  'exhausting': 2,
#  'corresponds': 2,
#  'possessed': 7,
#  'hartshorn': 2,
#  'unreliable': 1,
#  'cooks': 1,
#  'akin': 3,
#  'destroying': 2,
#  'maned': 2,
#  'resided': 1,
#  'slice': 1,
#  'Anomalous': 1,
#  'whispers': 3,
#  'revolving': 9,
#  'seated': 26,
#  'Anvil': 1,
#  'voted': 1,
#  'switching': 2,
#  'declining': 1,
#  'unsullied': 1,
#  'alleys': 1,
#  'integument': 1,
#  'meaning': 17,
#  'showers': 3,
#  'spoiled': 4,
#  'magnanimity': 1,
#  'bashfulness': 1,
#  'rib': 11,
#  'proudly': 3,
#  'duff': 1,
#  'apprise': 1,
#  'compress': 1,
#  'miscellaneous': 4,
#  'unprepared': 1,
#  'herein': 3,
#  'storm': 32,
#  'frame': 4,
#  'absurdly': 1,
#  'slipping': 5,
#  'doubt': 32,
#  'currents': 7,
#  'concussions': 1,
#  'unwarrantably': 2,
#  'marl': 1,
#  'griffins': 1,
#  'unique': 1,
#  'undivided': 1,
#  'sipping': 1,
#  'interrogatively': 1,
#  'boggy': 1,
#  'warehouse': 2,
#  'situation': 5,
#  'tumultuously': 2,
#  'sweeps': 1,
#  'Needle': 1,
#  'performances': 3,
#  'perpendicular': 11,
#  'bidden': 2,
#  '1': 2,
#  'Son': 3,
#  'hatchway': 7,
#  'withdrawal': 1,
#  'person': 28,
#  'Wall': 1,
#  'after': 252,
#  'recrossed': 1,
#  'VISITS': 1,
#  'laborious': 4,
#  'pots': 15,
#  'sketches': 2,
#  'any': 320,
#  'complies': 1,
#  'boisterous': 3,
#  'inward': 4,
#  'owe': 1,
#  'hulls': 5,
#  'festooned': 1,
#  'impression': 5,
#  'blasting': 1,
#  'procedure': 5,
#  'likenesses': 1,
#  'colder': 1,
#  'silken': 3,
#  'hard': 79,
#  'disembowelments': 1,
#  'STOWE': 1,
#  'Seldom': 1,
#  'desolateness': 1,
#  'accomplishing': 1,
#  'volume': 13,
#  'reasonest': 1,
#  'battering': 5,
#  'front': 25,
#  'SENTENCE': 1,
#  'Cheever': 1,
#  'bars': 2,
#  'thirteen': 2,
#  'opposite': 17,
#  'astral': 1,
#  'sich': 1,
#  'dorsal': 1,
#  'distortions': 1,
#  'tip': 3,
#  'flea': 2,
#  'unsettled': 1,
#  'knives': 10,
#  'superstitious': 10,
#  'bullets': 1,
#  'leaking': 2,
#  'discoveries': 1,
#  'delirium': 5,
#  'Hands': 6,
#  'shipyards': 1,
#  'surmise': 3,
#  'pilgrim': 2,
#  'bandied': 1,
#  '108': 1,
#  'Hither': 1,
#  'WAS': 1,
#  'dwells': 1,
#  'observations': 2,
#  'spademan': 1,
#  'repetitions': 1,
#  'pronounced': 5,
#  'cursed': 11,
#  'outfits': 2,
#  'skies': 9,
#  'sinful': 3,
#  'Harbor': 8,
#  'insurances': 1,
#  'ISOLATOES': 1,
#  'squeezing': 4,
#  'tethered': 1,
#  'undignified': 1,
#  'solo': 1,
#  'Beach': 2,
#  '"': 1478,
#  'sailmakers': 1,
#  'maty': 2,
#  'abominated': 1,
#  'appalling': 10,
#  'shrieks': 6,
#  'character': 14,
#  ':--"': 1,
#  'fist': 2,
#  'grappling': 1,
#  'impotently': 2,
#  'Supreme': 1,
#  'Killer': 2,
#  'outlandish': 6,
#  'distinguish': 4,
#  'arrested': 3,
#  'succeed': 4,
#  'Blind': 1,
#  'remarkably': 1,
#  'Socratic': 1,
#  'sails': 45,
#  'Herman': 1,
#  'attentively': 5,
#  'skill': 10,
#  'sideway': 1,
#  'impediments': 1,
#  'lances': 23,
#  'cords': 7,
#  'shepherd': 2,
#  'bodices': 1,
#  'ex': 1,
#  'Quebec': 2,
#  'overtake': 3,
#  'eagerly': 8,
#  'ninety': 7,
#  'bitterer': 1,
#  'vitiated': 1,
#  'propensity': 2,
#  'orbs': 2,
#  'upward': 5,
#  'patent': 2,
#  'Crossed': 2,
#  'Tartarian': 1,
#  'bows': 49,
#  'bullies': 1,
#  'unpainted': 1,
#  'Prick': 1,
#  'winter': 12,
#  'fuzzing': 1,
#  'slantings': 1,
#  'diligently': 7,
#  'paternal': 2,
#  'beholder': 1,
#  'aggrieved': 1,
#  'wonderments': 1,
#  'correct': 6,
#  'hurried': 7,
#  'blasts': 1,
#  'barometer': 1,
#  'trotting': 1,
#  'noblest': 3,
#  'curb': 1,
#  'Answer': 2,
#  'quoggy': 1,
#  'kneepans': 1,
#  'spring': 28,
#  'noways': 1,
#  'Plains': 1,
#  'Mazeppa': 1,
#  'developed': 3,
#  'appoint': 1,
#  'softener': 1,
#  'Indolence': 1,
#  'bedside': 1,
#  'conjoined': 2,
#  'LAY': 7,
#  'quaff': 1,
#  '25': 2,
#  'unreverenced': 1,
#  'Arkansas': 1,
#  'Bengal': 2,
#  'inflexibility': 1,
#  'Juba': 1,
#  'testily': 1,
#  'Canada': 2,
#  'greenly': 1,
#  'tape': 1,
#  'supply': 7,
#  'twilight': 5,
#  'octavo': 1,
#  'tackle': 11,
#  'tasted': 4,
#  'unbodied': 1,
#  'transports': 1,
#  'magnify': 1,
#  'argue': 3,
#  'intermeddling': 1,
#  'insulted': 3,
#  'mastership': 2,
#  'devotee': 1,
#  'Chestnut': 1,
#  'suppress': 1,
#  'bantam': 1,
#  'Stood': 1,
#  'would': 421,
#  'uncle': 2,
#  'perry': 2,
#  'realize': 1,
#  'Dantean': 1,
#  'Hydrus': 1,
#  'elsewhere': 11,
#  'cards': 4,
#  'Platonist': 1,
#  'bosom': 6,
#  'Affected': 1,
#  'besmoked': 1,
#  'prelusive': 1,
#  'succeeds': 1,
#  '66': 1,
#  'Unshored': 1,
#  'kennel': 1,
#  'aldermen': 1,
#  'Evil': 1,
#  'overmuch': 1,
#  'painted': 12,
#  'snake': 2,
#  'remotest': 10,
#  'mended': 2,
#  'Lascars': 1,
#  '500': 2,
#  "',--": 1,
#  'undertaker': 1,
#  'Satanic': 1,
#  'spoutings': 6,
#  'HEIGHT': 1,
#  'souls': 22,
#  'got': 46,
#  'Rondeletius': 1,
#  'rallied': 3,
#  'amend': 1,
#  'phrenologically': 3,
#  'skippers': 1,
#  'insurgents': 2,
#  'tack': 2,
#  'generalizing': 1,
#  'cobblestones': 1,
#  'Jaffa': 2,
#  'scoot': 1,
#  'Crappo': 1,
#  'gilded': 3,
#  'system': 9,
#  'watchmakers': 1,
#  'grass': 15,
#  'perches': 3,
#  'canonized': 1,
#  'mightily': 1,
#  'contributes': 2,
#  'spurrings': 1,
#  'persisted': 2,
#  'verbally': 3,
#  'Albicore': 1,
#  'exhibit': 1,
#  'companies': 5,
#  'Quakeress': 2,
#  'contest': 2,
#  'veracity': 1,
#  'neighbors': 3,
#  'beings': 9,
#  'repute': 1,
#  'lake': 9,
#  'cost': 1,
#  'total': 2,
#  'one': 889,
#  'lost': 45,
#  'slouched': 8,
#  'Apoplexy': 1,
#  'terribly': 1,
#  'lifted': 16,
#  'riveted': 5,
#  'expansion': 2,
#  'Erroneous': 1,
#  'crocodile': 2,
#  'transfixed': 1,
#  'when': 553,
#  'nest': 9,
#  'Glory': 1,
#  'further': 59,
#  'Thou': 39,
#  'led': 9,
#  'bruise': 1,
#  'WHARTON': 1,
#  'woodcock': 1,
#  'colony': 1,
#  'western': 7,
#  'fewer': 1,
#  'designation': 1,
#  'pretty': 28,
#  'OFF': 1,
#  'slain': 12,
#  'teachings': 2,
#  'circumspect': 1,
#  'maintains': 2,
#  'specific': 8,
#  'Others': 2,
#  'voyaging': 1,
#  'manipulator': 1,
#  'balanced': 3,
#  'mannikin': 1,
#  'lends': 1,
#  'skewered': 1,
#  'dentists': 1,
#  'Yojo': 17,
#  'aliment': 1,
#  'humorousness': 2,
#  'circulars': 1,
#  'incidentally': 7,
#  'dash': 7,
#  'stirs': 4,
#  'coppers': 1,
#  'counterfeit': 1,
#  'college': 1,
#  'germs': 1,
#  'vengeful': 5,
#  'Tisbury': 1,
#  'Bunyan': 1,
#  'spiritual': 11,
#  'HARDY': 1,
#  'gaspings': 1,
#  'ripple': 2,
#  'unworthy': 4,
#  'sixteen': 6,
#  'preciousness': 1,
#  'exhibited': 3,
#  'stubbornest': 1,
#  'starts': 4,
#  'GOES': 1,
#  'uncracked': 1,
#  'latter': 14,
#  'monster': 49,
#  'cymballing': 1,
#  'floated': 18,
#  'Hat': 1,
#  'Mohawk': 1,
#  'diagonically': 1,
#  'despot': 1,
#  'prolongings': 1,
#  'incommunicable': 3,
#  'o': 16,
#  'ribs': 20,
#  'intrepidity': 1,
#  'rending': 1,
#  'Convulsively': 1,
#  'emblematical': 2,
#  'gloom': 12,
#  'Scragg': 1,
#  'le': 1,
#  'UNPUBLISHED': 1,
#  'Instead': 1,
#  'wharf': 11,
#  'Platonists': 1,
#  'chatting': 2,
#  'depicting': 2,
#  'theory': 5,
#  'abjectly': 1,
#  'heavier': 2,
#  'summoned': 4,
#  'dramatic': 3,
#  'nightmare': 2,
#  'pelt': 3,
#  'unpleasant': 3,
#  'palsied': 2,
#  'rarities': 1,
#  'minutes': 21,
#  'TWO': 6,
#  'iciness': 1,
#  'ignorantly': 4,
#  'Swallow': 1,
#  'FIXED': 1,
#  'extend': 1,
#  'Wales': 1,
#  'Strangest': 1,
#  'acquiesce': 1,
#  'Mate': 1,
#  'coating': 1,
#  'education': 1,
#  'responses': 1,
#  'ceiling': 6,
#  'acuteness': 1,
#  'bivouacks': 1,
#  'gouty': 1,
#  'Blanc': 1,
#  'maternal': 5,
#  'paled': 1,
#  'flows': 4,
#  'Valparaiso': 1,
#  'whitest': 1,
#  'brawniness': 1,
#  'chimneys': 2,
#  'Christianity': 2,
#  'Rogers': 1,
#  'Matse': 1,
#  'archiepiscopacy': 1,
#  'Rib': 2,
#  'exert': 2,
#  'miscellaneously': 1,
#  'outstretching': 1,
#  'unspotted': 1,
#  'frankly': 3,
#  'razor': 2,
#  'forget': 11,
#  'ebbs': 1,
#  'fortune': 2,
#  'renown': 1,
#  '?--"': 1,
#  'commotion': 11,
#  'entrenched': 1,
#  'braiding': 1,
#  'Bible': 10,
#  'wisely': 1,
#  'enemy': 5,
#  'judicious': 1,
#  'happiness': 2,
#  'deserved': 3,
#  'Arnold': 1,
#  'drove': 3,
#  'Scoresby': 9,
#  'stalwart': 1,
#  'docile': 2,
#  'bulbous': 1,
#  'holiness': 1,
#  'spasmodic': 3,
#  'casks': 20,
#  'hove': 3,
#  'unrustlingly': 1,
#  'remorseless': 6,
#  'biscuits': 2,
#  '119': 1,
#  ...}

# %% [markdown]
# # DISTRIBUCIONES USANDO FREQDIST DE NLTK

# %%
from nltk.book import FreqDist
fdist = FreqDist(text1)
fdist.most_common(10)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982)]

# %%
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
fdist['whale']
# Out:
# 906

# %% [markdown]
# # FILTRADO AVANZADOS USANDO STOPWORDS

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {"wouldn't", 'you', 'theirs', 'under', 'before', 'herself', 'only', "isn't", 'is', 've', 'they', 'yourself', 'all', 'been', 'but', 'it', 'wasn', 'there', 'needn', 'which', "mightn't", 'who', 'doesn', 'he', 'down', 'too', 'hasn', 'here', 'can', 'ain', 'now', 'doing', "haven't", 'him', 'being', 'just', "needn't", 'does', 'mightn', "it'll", 'll', 'what', 'am', 'a', 'have', "hadn't", 'mustn', 'aren', 'off', 'themselves', 'yours', 'both', 'to', 're', 'why', 'hers', 'very', 'each', 'she', "couldn't", 'while', 'such', 'other', 'of', 'then', 'so', 'be', 'm', 'more', "you're", 'wouldn', 'whom', 'y', 'or', "she'll", "they'll", 'up', 'himself', 'than', "you've", "he's", 'her', 'from', 'on', 'ourselves', 'because', 'did', "didn't", 't', 'won', 'our', "weren't", 'his', 'as', 'was', 'will', "shouldn't", 'through', "i'd", 'about', "it's", 'above', 'itself', 'most', 'into', 'couldn', "he'd", 'this', 'i', "i'll", 'me', "i've", 'over', "she's", 'them', 'below', 'nor', 'my', "we're", 'had', "you'll", 'd', "wasn't", "he'll", "it'd", "she'd", 'weren', 'isn', 'by', 'own', 'hadn', 'their', 'in', "we'd", "i'm", 'having', "don't", "that'll", "we've", 's', 'when', 'further', 'are', 'again', 'for', "should've", 'ma', 'these', "doesn't", "hasn't", 'shan', "you'd", 'myself', 'your', 'yourselves', 'that', 'some', "they'd", 'and', 'same', 'those', "they're", 'shouldn', 'don', 'has', "shan't", 'where', 'should', 'didn', 'few', 'out', 'no', 'after', 'do', 'how', 'an', 'between', 'against', "won't", 'any', 'during', "they've", 'its', 'ours', 'with', 'the', 'haven', 'until', 'once', 'if', 'were', 'we', 'o', 'at', "aren't", "we'll", 'not', "mustn't"}

# %%
words = [word.lower() for word in text1 if word.isalpha()]
filtered_words = [word for word in words if word not in stop_words]
print(filtered_words[:10])
# Out:
# ['moby', 'dick', 'herman', 'melville', 'etymology', 'supplied', 'late', 'consumptive', 'usher', 'grammar']

# %% [markdown]
# # FRECUENCIA SIN STOPWORDS

# %%
fdist_filtered = FreqDist(filtered_words)
fdist_filtered.most_common(10)
# Out:
# [('whale', 1226),
#  ('one', 921),
#  ('like', 647),
#  ('upon', 566),
#  ('man', 527),
#  ('ship', 518),
#  ('ahab', 511),
#  ('ye', 472),
#  ('sea', 455),
#  ('old', 450)]

# %%
fdist_filtered.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
