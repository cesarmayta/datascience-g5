# %% [markdown]
# # EJEMPLO DE USO BASICO DE LA LIBRERIA NLTK PARA NLP
# ## [NLTK.ORG](https://www.nltk.org/)

# %% [markdown]
# # IMPORTAMOS Y DESCARGAMOS UN TEXTO EN ESPAÑOL

# %%
import nltk
nltk.download('cess_esp')
# Out:
# [nltk_data] Downloading package cess_esp to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cess_esp.zip.
# True

# %% [markdown]
# # CREAMOS UN CORPUS(COJUNTO DE TEXTOS)

# %%
corpus = nltk.corpus.cess_esp.sents()
corpus[1]
# Out:
# ['Una',
#  'portavoz',
#  'de',
#  'EDF',
#  'explicó',
#  'a',
#  'EFE',
#  'que',
#  'el',
#  'proyecto',
#  'para',
#  'la',
#  'construcción',
#  'de',
#  'Altamira_2',
#  ',',
#  'al',
#  'norte',
#  'de',
#  'Tampico',
#  ',',
#  'prevé',
#  'la',
#  'utilización',
#  'de',
#  'gas',
#  'natural',
#  'como',
#  'combustible',
#  'principal',
#  'en',
#  'una',
#  'central',
#  'de',
#  'ciclo',
#  'combinado',
#  'que',
#  'debe',
#  'empezar',
#  'a',
#  'funcionar',
#  'en',
#  'mayo_del_2002',
#  '.']

# %% [markdown]
# # REVISAMOS EL TOTAL DE TEXTOS DEL CORPUS

# %%
len(corpus)
# Out:
# 6030

# %% [markdown]
# # CONVERTIMOS EL CORPUS EN UNA SOLA LISTA DE PALABRAS

# %%
total_corpus = [w for l in corpus for w in l]
total_corpus[0:100]

# %%
len(total_corpus)
# Out:
# 192686

# %% [markdown]
# # FILTRANDO TEXTOS CON EXPRESIONES REGULARES

# %% [markdown]
# # BUSCAR TODAS LAS PALABRAS QUE CONTENGAS 'ES'

# %%
import re
arr = [w for w in total_corpus if re.search('es',w)]
arr[:10]
# Out:
# ['estatal',
#  'jueves',
#  'empresa',
#  'centrales',
#  'francesa',
#  'japonesa',
#  'millones',
#  'millones',
#  'dólares',
#  'millones']

# %% [markdown]
# # BUSCAR TODAS PALABRAS QUE TENGAS J T DENTRO DE LA PALABRA EN ESE ORDEN

# %%
arr = [w for w in total_corpus if re.search('^..j..t..$',w)]
arr
# Out:
# ['tajantes']
