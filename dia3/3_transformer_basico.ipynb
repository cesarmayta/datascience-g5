# %% [markdown]
# # CREANDO UNA RED NEURONAL TRANSFORMER BASICA

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# # Definimos el modelo Transformer

# %% [markdown]
# # PARAMETROS

# %%
input_dim = 5  # Se puede pensar como el vocabulario de números (1, 2, 3, 4, 5)
output_dim = 1  # Solo predecimos un valor
hidden_dim = 16  # Dimensión interna de los embeddings
num_heads = 2  # Número de cabezas de atención
num_layers = 2  # Número de capas en el transformer

# %% [markdown]
# # CREAMOS CLASE TRANSFORMER

# %%
class TransformerModel(nn.Module):
    def __init__(self,input_dim,hidden_dim,num_heads,num_layers,output_dim):
        super(TransformerModel, self).__init__()

        # definimos una capa para embedding
        self.embedding = nn.Embedding(input_dim,hidden_dim)

        # creamos una capa para el transformer(con encoder y decoder)
        self.transformer = nn.Transformer(d_model=hidden_dim,nhead=num_heads,num_encoder_layers=num_layers,num_decoder_layers=num_layers)

        # capa de salida(para la predicción final)
        self.fc_out = nn.Linear(hidden_dim,output_dim)

    def forward(self,src,tgt):
        #Embedding para la secuencia de entrada y secuencia de salida
        src = self.embedding(src)
        tgt = self.embedding(tgt)

        # Transformer genera una representación codificada
        output = self.transformer(src,tgt)

        # Pasamos la representación codificada a la capa de salida
        out = self.fc_out(output[-1,:,:])

        return out

# %% [markdown]
# # Crear el modelo Transformer

# %%
model = TransformerModel(input_dim=input_dim,
                         hidden_dim=hidden_dim,
                         num_heads=num_heads,
                         num_layers=num_layers,
                         output_dim=output_dim)

# %% [markdown]
# # Optimización y criterio

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # Datos de entrada: secuencia y objetivo (por ejemplo, [1, 2, 3] → 4)

# %%
src = torch.tensor([[1, 2, 3]]).T  # (3, 1) -> Forma correcta para el transformer
tgt = torch.tensor([[2, 3, 4]]).T  # (3, 1) -> Forma correcta para el transformer

# %% [markdown]
# # Entrenamiento

# %%
num_epochs = 300
for epoch in range(num_epochs):
    model.train()

    # Forward pass
    output = model(src, tgt)

    # Cálculo de la pérdida
    loss = criterion(output, torch.tensor([[5.0]]))  # Queremos predecir 5

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 50 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.4f}, Predicción: {output.item():.4f}")
# Out:
# Epoch 0, Loss: 33.6117, Predicción: -0.7976
# Epoch 50, Loss: 3.3423, Predicción: 3.1718
# Epoch 100, Loss: 0.9793, Predicción: 4.0104
# Epoch 150, Loss: 0.1064, Predicción: 4.6738
# Epoch 200, Loss: 0.0077, Predicción: 4.9123
# Epoch 250, Loss: 0.0054, Predicción: 4.9265
