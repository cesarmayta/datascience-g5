# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 📈 1. Gráfico de líneas
#
# Se utiliza para visualizar tendencias o evolución de datos en el tiempo.

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]

plt.plot(x,y,marker='o',linestyle='-',color='blue')
plt.show()

# %% [markdown]
# ## 📊 2. Gráfico de barras
#
# Útil para comparar cantidades entre distintas categorías.

# %%
categorias = ['A', 'B', 'C', 'D']
valores = [40, 70, 30, 85]

plt.bar(categorias,valores,color='orange')
plt.show()

# %%
plt.barh(categorias,valores,color='green')
plt.show()

# %% [markdown]
# ## 🧁 4. Gráfico de pastel (pie chart)
#
# Muestra proporciones relativas de un total.

# %%
etiquetas = ['Manzanas', 'Plátanos', 'Peras']
tamaños = [30, 50, 20]

plt.pie(tamaños,labels=etiquetas,startangle=90,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## 🔘 5. Gráfico de dispersión (scatter plot)
#
# Ideal para observar correlaciones entre dos variables numéricas.

# %%
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.09426718, 0.95291831, 0.95790356, 0.44720408, 0.85454402,
#        0.34026559, 0.63484909, 0.39513817, 0.96709133, 0.49769482,
#        0.05797633, 0.52051186, 0.66535203, 0.39363795, 0.08613211,
#        0.04151592, 0.49727667, 0.29238409, 0.89269465, 0.68926551,
#        0.95555188, 0.01435727, 0.61403616, 0.47544891, 0.81259617,
#        0.86191217, 0.76527717, 0.34554246, 0.55161782, 0.11003171,
#        0.52936106, 0.14570172, 0.58615683, 0.19244589, 0.35526271,
#        0.21362859, 0.7751988 , 0.07358755, 0.78892378, 0.66417396,
#        0.05427922, 0.07736615, 0.40663012, 0.57950906, 0.89289809,
#        0.54298326, 0.21614118, 0.09137652, 0.15902037, 0.02457536])

# %%
y
# Out:
# array([0.09170764, 0.21986234, 0.91150216, 0.40720498, 0.45376733,
#        0.7365654 , 0.39802624, 0.97259548, 0.67767907, 0.81303957,
#        0.05833614, 0.64397373, 0.22274082, 0.35653809, 0.10103125,
#        0.38455467, 0.8377042 , 0.8905935 , 0.06975605, 0.69736301,
#        0.450401  , 0.14342419, 0.65002943, 0.21610761, 0.20255294,
#        0.5547275 , 0.06696945, 0.90183799, 0.51642777, 0.25341103,
#        0.05170163, 0.67494263, 0.84100353, 0.16116126, 0.61715669,
#        0.72805638, 0.59255422, 0.22202787, 0.71738635, 0.33909476,
#        0.24997842, 0.95021668, 0.45863038, 0.44562385, 0.19635804,
#        0.9886132 , 0.45942238, 0.51239479, 0.58868521, 0.10836087])

# %%
plt.scatter(x,y,color='blue')
plt.show()

# %% [markdown]
# ## 📊 6. Histograma
#
# Muestra la distribución de frecuencia de una variable continua.

# %%
datos = np.random.randn(1000)

plt.hist(datos,bins=30,color='orange',edgecolor='black')
plt.show()

# %% [markdown]
# ## 📦 7. Diagrama de caja (boxplot)
#
# Útil para detectar valores atípicos y ver la distribución.

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]
data
# Out:
# [array([ 0.2896964 , -0.14538162, -0.51269067, -0.66725359,  0.34812122,
#         -0.37649716,  0.38418706, -1.29461403,  0.58978768,  0.65958436,
#          0.91024356, -0.33203549, -0.15970104,  0.4893639 , -1.10901563,
#          0.09658999, -0.0940648 , -0.19290584,  1.91608351,  0.69839001,
#          0.85844572,  1.3672499 , -1.87250136,  0.57619198, -1.13320404,
#          0.33923828, -0.46205182,  0.37178303,  0.04594877,  1.12101952,
#         -1.69991468,  0.16701531,  0.07730123,  0.36735404, -1.579887  ,
#         -0.4312946 ,  0.39163522, -1.01016487,  1.11524516, -0.87639653,
#         -0.48642103, -0.58855005,  0.40865115, -0.82080712,  1.22207378,
#         -0.79061061,  1.01259272,  1.96781939, -1.79104988, -2.75995198,
#         -0.58118648,  1.14966741,  0.27814149, -0.04265766,  0.91450641,
#         -1.71171612, -0.21933975,  0.08663347, -0.76186635,  1.0005734 ,
#          0.4150843 ,  0.87590146,  1.73308889, -0.44135801,  0.6864208 ,
#         -0.89189859, -0.98345201, -2.9449757 , -0.25564926, -0.58545673,
#         -0.70862183,  0.7827628 ,  0.31344265, -1.5217677 ,  0.43938212,
#          1.04468665, -0.2780245 ,  2.28079833, -0.15308255,  1.01509131,
#          0.34629073, -0.53132527,  0.70381796,  0.89547179, -0.28014515,
#          0.60586888, -0.12485419,  0.54233823,  0.22258756, -0.45759369,
#          0.12726824,  1.85501996, -0.02068129, -0.91268902, -0.30909835,
#          0.89036731, -0.00688649, -0.99094068, -0.54489946,  2.41542764]),
#  array([-1.12134589, -2.63377122,  2.91497123,  0.42818683,  3.54242194,
#          0.48943826, -0.52646501, -1.15412174, -0.75231372, -3.09840288,
#         -0.86441801,  0.86132729,  0.22379829,  1.50821279,  2.44037782,
#          1.23939603,  0.116118  , -0.48261703, -2.24204694,  1.2814034 ,
#          3.07968552,  1.04126746, -0.85206448, -3.16055252, -3.16943728,
#         -1.02768967,  1.30069839,  2.8225405 , -1.05662901, -0.91960251,
#          4.56250529,  1.68562231,  0.89764502,  0.76781965,  0.56382889,
